# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait

# %%
link = 'https://www.imdb.com/'

# %%
driver = webdriver.Firefox()
driver.maximize_window()

# %%
driver.get(link)

# %%
menu = driver.find_element(By.XPATH, '//*[@id="imdbHeader-navDrawerOpen"]')
menu.click()

# %%
top_250_series = menu.find_element(By.XPATH, '/html/body/div[2]/nav/div/aside[1]/div/div[2]/div/div[2]/div[1]/span/div/div/ul/a[2]/span')
top_250_series.click()

# %%
tabela_series = driver.find_element(By.XPATH, '/html/body/div[2]/main/div/div[3]/section/div/div[2]/div/ul')

# %%
series = []

lista_series = tabela_series.find_elements(By.CLASS_NAME, 'ipc-metadata-list-summary-item')
tam = len(lista_series)
i = 1
for serie in lista_series:
    print(f"{i}/{tam}")
    
    metadados = []
    for meta in serie.find_elements(By.CLASS_NAME, 'cli-title-metadata-item'):
        metadados.append(meta.text)
        data = metadados[0].split('–')

    dicionario_series = {
        'Título': " ".join(serie.find_element(By.CLASS_NAME, 'ipc-title-link-wrapper').text.split()[1:]),
        'Ano de estreia': data[0],
        'Ano de encerramento': data[1] if len(data) > 1 else None,
        'Número Total de Episódios': metadados[1].split()[0],
        'Classificação indicativa': metadados[2] if len(metadados) > 2 else None,
        'Nota do IMDB': serie.find_element(By.CLASS_NAME, 'ipc-rating-star--rating').text,
        'Link': serie.find_element(By.CLASS_NAME, 'ipc-title-link-wrapper').get_attribute("href"),
        'Popularidade': None,
        'Atores': []
    }

    series.append(dicionario_series)
    i += 1
# Out:
# 1/250
# 2/250
# 3/250
# 4/250
# 5/250
# 6/250
# 7/250
# 8/250
# 9/250
# 10/250
# 11/250
# 12/250
# 13/250
# 14/250
# 15/250
# 16/250
# 17/250
# 18/250
# 19/250
# 20/250
# 21/250
# 22/250
# 23/250
# 24/250
# 25/250
# 26/250
# 27/250
# 28/250
# 29/250
# 30/250
# 31/250
# 32/250
# 33/250
# 34/250
# 35/250
# 36/250
# 37/250
# 38/250
# 39/250
# 40/250
# 41/250
# 42/250
# 43/250
# 44/250
# 45/250
# 46/250
# 47/250
# 48/250
# 49/250
# 50/250
# 51/250
# 52/250
# 53/250
# 54/250
# 55/250
# 56/250
# 57/250
# 58/250
# 59/250
# 60/250
# 61/250
# 62/250
# 63/250
# 64/250
# 65/250
# 66/250
# 67/250
# 68/250
# 69/250
# 70/250
# 71/250
# 72/250
# 73/250
# 74/250
# 75/250
# 76/250
# 77/250
# 78/250
# 79/250
# 80/250
# 81/250
# 82/250
# 83/250
# 84/250
# 85/250
# 86/250
# 87/250
# 88/250
# 89/250
# 90/250
# 91/250
# 92/250
# 93/250
# 94/250
# 95/250
# 96/250
# 97/250
# 98/250
# 99/250
# 100/250
# 101/250
# 102/250
# 103/250
# 104/250
# 105/250
# 106/250
# 107/250
# 108/250
# 109/250
# 110/250
# 111/250
# 112/250
# 113/250
# 114/250
# 115/250
# 116/250
# 117/250
# 118/250
# 119/250
# 120/250
# 121/250
# 122/250
# 123/250
# 124/250
# 125/250
# 126/250
# 127/250
# 128/250
# 129/250
# 130/250
# 131/250
# 132/250
# 133/250
# 134/250
# 135/250
# 136/250
# 137/250
# 138/250
# 139/250
# 140/250
# 141/250
# 142/250
# 143/250
# 144/250
# 145/250
# 146/250
# 147/250
# 148/250
# 149/250
# 150/250
# 151/250
# 152/250
# 153/250
# 154/250
# 155/250
# 156/250
# 157/250
# 158/250
# 159/250
# 160/250
# 161/250
# 162/250
# 163/250
# 164/250
# 165/250
# 166/250
# 167/250
# 168/250
# 169/250
# 170/250
# 171/250
# 172/250
# 173/250
# 174/250
# 175/250
# 176/250
# 177/250
# 178/250
# 179/250
# 180/250
# 181/250
# 182/250
# 183/250
# 184/250
# 185/250
# 186/250
# 187/250
# 188/250
# 189/250
# 190/250
# 191/250
# 192/250
# 193/250
# 194/250
# 195/250
# 196/250
# 197/250
# 198/250
# 199/250
# 200/250
# 201/250
# 202/250
# 203/250
# 204/250
# 205/250
# 206/250
# 207/250
# 208/250
# 209/250
# 210/250
# 211/250
# 212/250
# 213/250
# 214/250
# 215/250
# 216/250
# 217/250
# 218/250
# 219/250
# 220/250
# 221/250
# 222/250
# 223/250
# 224/250
# 225/250
# 226/250
# 227/250
# 228/250
# 229/250
# 230/250
# 231/250
# 232/250
# 233/250
# 234/250
# 235/250
# 236/250
# 237/250
# 238/250
# 239/250
# 240/250
# 241/250
# 242/250
# 243/250
# 244/250
# 245/250
# 246/250
# 247/250
# 248/250
# 249/250
# 250/250

# %%
for s in series[:5]:
    print(f"Coletando dados da série: {s['Título']}")
    link = s['Link']
    
    driver.get(link)

    rating_bar_pop = driver.find_element(By.CSS_SELECTOR, '[data-testid="hero-rating-bar__popularity__score"]')
    s['Popularidade'] = rating_bar_pop.text

    cast = driver.find_element(By.CSS_SELECTOR, '[data-testid="title-cast"]')
    cast_actors = cast.find_elements(By.CSS_SELECTOR, '[data-testid="title-cast-item"]')

    for actor in cast_actors:
        metadados = actor.text.split('\n')
        dict_ator = {
            'Nome Ator': metadados[0],
            'Personagem/Papel': metadados[1],
            'Quantidade de Episódios': metadados[2].split()[0]
        }
        
        s['Atores'].append(dict_ator)
# Out:
# Coletando dados da série: Breaking Bad
# Coletando dados da série: Planet Earth II
# Coletando dados da série: Planet Earth
# Coletando dados da série: Band of Brothers
# Coletando dados da série: Chernobyl

# %%
series[:5]
# Out:
# [{'Título': 'Breaking Bad',
#   'Ano de estreia': '2008',
#   'Ano de encerramento': '2013',
#   'Número Total de Episódios': '62',
#   'Classificação indicativa': 'TV-MA',
#   'Nota do IMDB': '9.5',
#   'Link': 'https://www.imdb.com/title/tt0903747/?ref_=chttvtp_t_1',
#   'Popularidade': '12',
#   'Atores': [{'Nome Ator': 'Bryan Cranston',
#     'Personagem/Papel': 'Walter White',
#     'Quantidade de Episódios': '62'},
#    {'Nome Ator': 'Aaron Paul',
#     'Personagem/Papel': 'Jesse Pinkman',
#     'Quantidade de Episódios': '62'},
#    {'Nome Ator': 'Anna Gunn',
#     'Personagem/Papel': 'Skyler White',
#     'Quantidade de Episódios': '62'},
#    {'Nome Ator': 'Betsy Brandt',
#     'Personagem/Papel': 'Marie Schrader',
#     'Quantidade de Episódios': '62'},
#    {'Nome Ator': 'RJ Mitte',
#     'Personagem/Papel': 'Walter White, Jr.',
#     'Quantidade de Episódios': '62'},
#    {'Nome Ator': 'Dean Norris',
#     'Personagem/Papel': 'Hank Schrader',
#     'Quantidade de Episódios': '62'},
#    {'Nome Ator': 'Bob Odenkirk',
#     'Personagem/Papel': 'Saul Goodman',
#     'Quantidade de Episódios': '43'},
#    {'Nome Ator': 'Steven Michael Quezada',
#     'Personagem/Papel': 'Steven Gomez',
#     'Quantidade de Episódios': '34'},
#    {'Nome Ator': 'Jonathan Banks',
#     'Personagem/Papel': 'Mike Ehrmantraut',
#     'Quantidade de Episódios': '28'},
#    {'Nome Ator': 'Giancarlo Esposito',
#     'Personagem/Papel': 'Gus Fring',
#     'Quantidade de Episódios': '26'},
#    {'Nome Ator': 'Charles Baker',
#     'Personagem/Papel': 'Skinny Pete',
#     'Quantidade de Episódios': '15'},
#    {'Nome Ator': 'Jesse Plemons',
#     'Personagem/Papel': 'Todd',
#     'Quantidade de Episódios': '13'},
#    {'Nome Ator': 'Christopher Cousins',
#     'Personagem/Papel': 'Ted Beneke',
#     'Quantidade de Episódios': '13'},
#    {'Nome Ator': 'Laura Fraser',
#     'Personagem/Papel': 'Lydia Rodarte-Quayle',
#     'Quantidade de Episódios': '12'},
#    {'Nome Ator': 'Matt Jones',
#     'Personagem/Papel': 'Badger',
#     'Quantidade de Episódios': '12'},
#    {'Nome Ator': 'Michael Shamus Wiles',
#     'Personagem/Papel': 'ASAC George Merkert',
#     'Quantidade de Episódios': '11'},
#    {'Nome Ator': 'Lavell Crawford',
#     'Personagem/Papel': 'Huell',
#     'Quantidade de Episódios': '11'},
#    {'Nome Ator': 'Ray Campbell',
#     'Personagem/Papel': 'Tyrus Kitt',
#     'Quantidade de Episódios': '10'},
#    {'Nome Ator': 'Bryan Cranston',
#     'Personagem/Papel': 'Walter White',
#     'Quantidade de Episódios': '62'},
#    {'Nome Ator': 'Aaron Paul',
#     'Personagem/Papel': 'Jesse Pinkman',
#     'Quantidade de Episódios': '62'},
#    {'Nome Ator': 'Anna Gunn',
#     'Personagem/Papel': 'Skyler White',
#     'Quantidade de Episódios': '62'},
#    {'Nome Ator': 'Betsy Brandt',
#     'Personagem/Papel': 'Marie Schrader',
#     'Quantidade de Episódios': '62'},
#    {'Nome Ator': 'RJ Mitte',
#     'Personagem/Papel': 'Walter White, Jr.',
#     'Quantidade de Episódios': '62'},
#    {'Nome Ator': 'Dean Norris',
#     'Personagem/Papel': 'Hank Schrader',
#     'Quantidade de Episódios': '62'},
#    {'Nome Ator': 'Bob Odenkirk',
#     'Personagem/Papel': 'Saul Goodman',
#     'Quantidade de Episódios': '43'},
#    {'Nome Ator': 'Steven Michael Quezada',
#     'Personagem/Papel': 'Steven Gomez',
#     'Quantidade de Episódios': '34'},
#    {'Nome Ator': 'Jonathan Banks',
#     'Personagem/Papel': 'Mike Ehrmantraut',
#     'Quantidade de Episódios': '28'},
#    {'Nome Ator': 'Giancarlo Esposito',
#     'Personagem/Papel': 'Gus Fring',
#     'Quantidade de Episódios': '26'},
#    {'Nome Ator': 'Charles Baker',
#     'Personagem/Papel': 'Skinny Pete',
#     'Quantidade de Episódios': '15'},
#    {'Nome Ator': 'Jesse Plemons',
#     'Personagem/Papel': 'Todd',
#     'Quantidade de Episódios': '13'},
#    {'Nome Ator': 'Christopher Cousins',
#     'Personagem/Papel': 'Ted Beneke',
#     'Quantidade de Episódios': '13'},
#    {'Nome Ator': 'Laura Fraser',
#     'Personagem/Papel': 'Lydia Rodarte-Quayle',
#     'Quantidade de Episódios': '12'},
#    {'Nome Ator': 'Matt Jones',
#     'Personagem/Papel': 'Badger',
#     'Quantidade de Episódios': '12'},
#    {'Nome Ator': 'Michael Shamus Wiles',
#     'Personagem/Papel': 'ASAC George Merkert',
#     'Quantidade de Episódios': '11'},
#    {'Nome Ator': 'Lavell Crawford',
#     'Personagem/Papel': 'Huell',
#     'Quantidade de Episódios': '11'},
#    {'Nome Ator': 'Ray Campbell',
#     'Personagem/Papel': 'Tyrus Kitt',
#     'Quantidade de Episódios': '10'}]},
#  {'Título': 'Planet Earth II',
#   'Ano de estreia': '2016',
#   'Ano de encerramento': None,
#   'Número Total de Episódios': '6',
#   'Classificação indicativa': 'TV-G',
#   'Nota do IMDB': '9.4',
#   'Link': 'https://www.imdb.com/title/tt5491994/?ref_=chttvtp_t_2',
#   'Popularidade': '558',
#   'Atores': [{'Nome Ator': 'David Attenborough',
#     'Personagem/Papel': 'Self - Narrator',
#     'Quantidade de Episódios': '6'},
#    {'Nome Ator': 'Gordon Buchanan',
#     'Personagem/Papel': 'Self - Cameraman',
#     'Quantidade de Episódios': '1'},
#    {'Nome Ator': 'Chadden Hunter',
#     'Personagem/Papel': 'Self - Producer',
#     'Quantidade de Episódios': '1'},
#    {'Nome Ator': 'Ed Charles',
#     'Personagem/Papel': 'Self - Producer',
#     'Quantidade de Episódios': '1'},
#    {'Nome Ator': 'Toby Nowlan',
#     'Personagem/Papel': 'Self - Researcher',
#     'Quantidade de Episódios': '1'},
#    {'Nome Ator': 'Mark MacEwen',
#     'Personagem/Papel': 'Self - Cameraman',
#     'Quantidade de Episódios': '1'},
#    {'Nome Ator': 'Michael J. Sanderson',
#     'Personagem/Papel': 'Self - Drone Operator',
#     'Quantidade de Episódios': '1'},
#    {'Nome Ator': 'Barrie Britton',
#     'Personagem/Papel': 'Self - Cameraman',
#     'Quantidade de Episódios': '1'},
#    {'Nome Ator': 'Pete McCowen',
#     'Personagem/Papel': 'Self - Cameraman',
#     'Quantidade de Episódios': '1'},
#    {'Nome Ator': 'Fredi Devas',
#     'Personagem/Papel': 'Self - Producer',
#     'Quantidade de Episódios': '1'},
#    {'Nome Ator': 'Rob Drewett',
#     'Personagem/Papel': 'Self - Cameraman',
#     'Quantidade de Episódios': '1'},
#    {'Nome Ator': 'Sandesh Kadur',
#     'Personagem/Papel': 'Self - Cameraman',
#     'Quantidade de Episódios': '1'},
#    {'Nome Ator': 'Max Hug Williams',
#     'Personagem/Papel': 'Self - Cameraman',
#     'Quantidade de Episódios': '1'},
#    {'Nome Ator': 'Emma Napper',
#     'Personagem/Papel': 'Self - Producer',
#     'Quantidade de Episódios': '1'},
#    {'Nome Ator': 'Elizabeth White',
#     'Personagem/Papel': 'Self - Producer',
#     'Quantidade de Episódios': '1'},
#    {'Nome Ator': 'Thomas Crowley',
#     'Personagem/Papel': 'Self - Cameraman',
#     'Quantidade de Episódios': '1'},
#    {'Nome Ator': 'Juarez Sena Feitoza',
#     'Personagem/Papel': 'Self - Field Assistant',
#     'Quantidade de Episódios': '1'},
#    {'Nome Ator': 'Jerome Poncet',
#     'Personagem/Papel': 'Self - Antarctic expert',
#     'Quantidade de Episódios': '1'}]},
#  {'Título': 'Planet Earth',
#   'Ano de estreia': '2006',
#   'Ano de encerramento': None,
#   'Número Total de Episódios': '11',
#   'Classificação indicativa': 'TV-PG',
#   'Nota do IMDB': '9.4',
#   'Link': 'https://www.imdb.com/title/tt0795176/?ref_=chttvtp_t_3',
#   'Popularidade': '880',
#   'Atores': [{'Nome Ator': 'Sigourney Weaver',
#     'Personagem/Papel': 'Narrator - US Version',
#     'Quantidade de Episódios': '11'},
#    {'Nome Ator': 'David Attenborough',
#     'Personagem/Papel': 'Self - Narrator',
#     'Quantidade de Episódios': '11'},
#    {'Nome Ator': 'Nikolay Drozdov',
#     'Personagem/Papel': 'Narrator',
#     'Quantidade de Episódios': '11'},
#    {'Nome Ator': 'Thomas Anguti Johnston',
#     'Personagem/Papel': 'Inuktitut Narrator',
#     'Quantidade de Episódios': '11'},
#    {'Nome Ator': 'Sanae Ueda',
#     'Personagem/Papel': 'Self - Narrator Japan',
#     'Quantidade de Episódios': '11'},
#    {'Nome Ator': 'Huw Cordey',
#     'Personagem/Papel': 'Self - Producer…',
#     'Quantidade de Episódios': '3'},
#    {'Nome Ator': 'Doug Allan',
#     'Personagem/Papel': 'Self',
#     'Quantidade de Episódios': '2'},
#    {'Nome Ator': 'Mark Linfield',
#     'Personagem/Papel': 'Self…',
#     'Quantidade de Episódios': '2'},
#    {'Nome Ator': 'Paul Stewart',
#     'Personagem/Papel': 'Self',
#     'Quantidade de Episódios': '1'},
#    {'Nome Ator': 'Chadden Hunter',
#     'Personagem/Papel': 'Self - Field Assistant',
#     'Quantidade de Episódios': '1'},
#    {'Nome Ator': 'Jeff Wilson',
#     'Personagem/Papel': 'Self',
#     'Quantidade de Episódios': '1'},
#    {'Nome Ator': 'Doug Anderson',
#     'Personagem/Papel': 'Self',
#     'Quantidade de Episódios': '1'},
#    {'Nome Ator': 'Michael Kelem',
#     'Personagem/Papel': 'Self',
#     'Quantidade de Episódios': '1'},
#    {'Nome Ator': 'Justine Evans',
#     'Personagem/Papel': 'Self',
#     'Quantidade de Episódios': '1'},
#    {'Nome Ator': 'Jonathan Keeling',
#     'Personagem/Papel': 'Self',
#     'Quantidade de Episódios': '1'},
#    {'Nome Ator': 'Rick Rosenthal',
#     'Personagem/Papel': 'Self',
#     'Quantidade de Episódios': '1'},
#    {'Nome Ator': 'Simon King',
#     'Personagem/Papel': 'Self',
#     'Quantidade de Episódios': '1'},
#    {'Nome Ator': 'Warwick Sloss',
#     'Personagem/Papel': 'Self - Cameraman',
#     'Quantidade de Episódios': '1'}]},
#  {'Título': 'Band of Brothers',
#   'Ano de estreia': '2001',
#   'Ano de encerramento': None,
#   'Número Total de Episódios': '10',
#   'Classificação indicativa': 'TV-MA',
#   'Nota do IMDB': '9.4',
#   'Link': 'https://www.imdb.com/title/tt0185906/?ref_=chttvtp_t_4',
#   'Popularidade': '119',
#   'Atores': [{'Nome Ator': 'Scott Grimes',
#     'Personagem/Papel': 'Donald G. Malarkey',
#     'Quantidade de Episódios': '10'},
#    {'Nome Ator': 'Damian Lewis',
#     'Personagem/Papel': 'Richard D. Winters',
#     'Quantidade de Episódios': '10'},
#    {'Nome Ator': 'Ron Livingston',
#     'Personagem/Papel': 'Lewis Nixon',
#     'Quantidade de Episódios': '10'},
#    {'Nome Ator': 'Shane Taylor',
#     'Personagem/Papel': 'Eugene G. Roe',
#     'Quantidade de Episódios': '10'},
#    {'Nome Ator': 'Donnie Wahlberg',
#     'Personagem/Papel': 'C. Carwood Lipton',
#     'Quantidade de Episódios': '10'},
#    {'Nome Ator': 'Peter Youngblood Hills',
#     'Personagem/Papel': 'Darrell C. (Shifty) Powers',
#     'Quantidade de Episódios': '10'},
#    {'Nome Ator': 'Matthew Leitch',
#     'Personagem/Papel': 'Floyd M. (Tab) Talbert',
#     'Quantidade de Episódios': '10'},
#    {'Nome Ator': 'Nicholas Aaron',
#     'Personagem/Papel': 'Robert E. (Popeye) Wynn',
#     'Quantidade de Episódios': '9'},
#    {'Nome Ator': 'Philip Barantini',
#     'Personagem/Papel': 'Wayne A. (Skinny) Sisk',
#     'Quantidade de Episódios': '9'},
#    {'Nome Ator': 'Michael Cudlitz',
#     'Personagem/Papel': 'Denver (Bull) Randleman',
#     'Quantidade de Episódios': '9'},
#    {'Nome Ator': 'Dexter Fletcher',
#     'Personagem/Papel': 'John W. Martin',
#     'Quantidade de Episódios': '9'},
#    {'Nome Ator': 'Rick Gomez',
#     'Personagem/Papel': 'George Luz',
#     'Quantidade de Episódios': '9'},
#    {'Nome Ator': 'James Madio',
#     'Personagem/Papel': 'Frank J. Perconte',
#     'Quantidade de Episódios': '9'},
#    {'Nome Ator': 'Ross McCall',
#     'Personagem/Papel': 'Joseph D. Liebgott',
#     'Quantidade de Episódios': '9'},
#    {'Nome Ator': 'Doug Allen',
#     'Personagem/Papel': 'Alton M. More',
#     'Quantidade de Episódios': '8'},
#    {'Nome Ator': 'George Calil',
#     'Personagem/Papel': 'James H. (Mo) Alley Jr.',
#     'Quantidade de Episódios': '8'},
#    {'Nome Ator': 'Nolan Hemmings',
#     'Personagem/Papel': 'Charles E. (Chuck) Grant',
#     'Quantidade de Episódios': '8'},
#    {'Nome Ator': 'Robin Laing',
#     'Personagem/Papel': 'Edward J. (Babe) Heffron',
#     'Quantidade de Episódios': '8'}]},
#  {'Título': 'Chernobyl',
#   'Ano de estreia': '2019',
#   'Ano de encerramento': None,
#   'Número Total de Episódios': '5',
#   'Classificação indicativa': 'TV-MA',
#   'Nota do IMDB': '9.3',
#   'Link': 'https://www.imdb.com/title/tt7366338/?ref_=chttvtp_t_5',
#   'Popularidade': '107',
#   'Atores': [{'Nome Ator': 'Jessie Buckley',
#     'Personagem/Papel': 'Lyudmilla Ignatenko',
#     'Quantidade de Episódios': '5'},
#    {'Nome Ator': 'Jared Harris',
#     'Personagem/Papel': 'Valery Legasov',
#     'Quantidade de Episódios': '5'},
#    {'Nome Ator': 'Stellan Skarsgård',
#     'Personagem/Papel': 'Boris Shcherbina',
#     'Quantidade de Episódios': '5'},
#    {'Nome Ator': 'Adam Nagaitis',
#     'Personagem/Papel': 'Vasily Ignatenko',
#     'Quantidade de Episódios': '4'},
#    {'Nome Ator': 'Emily Watson',
#     'Personagem/Papel': 'Ulana Khomyuk',
#     'Quantidade de Episódios': '4'},
#    {'Nome Ator': 'Paul Ritter',
#     'Personagem/Papel': 'Anatoly Dyatlov',
#     'Quantidade de Episódios': '4'},
#    {'Nome Ator': 'Robert Emms',
#     'Personagem/Papel': 'Leonid Toptunov',
#     'Quantidade de Episódios': '4'},
#    {'Nome Ator': 'Sam Troughton',
#     'Personagem/Papel': 'Alexandr Akimov',
#     'Quantidade de Episódios': '4'},
#    {'Nome Ator': 'Karl Davies',
#     'Personagem/Papel': 'Viktor Proskuryakov',
#     'Quantidade de Episódios': '3'},
#    {'Nome Ator': 'Michael Socha',
#     'Personagem/Papel': 'Mikhail',
#     'Quantidade de Episódios': '3'},
#    {'Nome Ator': 'Laura Elphinstone',
#     'Personagem/Papel': 'Oksana',
#     'Quantidade de Episódios': '3'},
#    {'Nome Ator': 'Jan Ricica',
#     'Personagem/Papel': "Oksana's Kid",
#     'Quantidade de Episódios': '3'},
#    {'Nome Ator': 'Adrian Rawlins',
#     'Personagem/Papel': 'Nikolai Fomin',
#     'Quantidade de Episódios': '3'},
#    {'Nome Ator': 'Alan Williams',
#     'Personagem/Papel': 'KGB Chairman Charkov',
#     'Quantidade de Episódios': '3'},
#    {'Nome Ator': "Con O'Neill",
#     'Personagem/Papel': 'Viktor Bryukhanov',
#     'Quantidade de Episódios': '3'},
#    {'Nome Ator': 'Douggie McMeekin',
#     'Personagem/Papel': 'Yuvchenko',
#     'Quantidade de Episódios': '2'},
#    {'Nome Ator': 'Nadia Clifford',
#     'Personagem/Papel': 'Dr. Svetlana Zinchenko',
#     'Quantidade de Episódios': '2'},
#    {'Nome Ator': 'David Dencik',
#     'Personagem/Papel': 'Mikhail Gorbachev',
#     'Quantidade de Episódios': '2'}]}]
